# %%
# !pip install transformers
# !pip install datasets
# !pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 15.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 20.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 27.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.6 MB/s eta 0:00:00
# ...

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('multi-qa-MiniLM-L6-cos-v1')

# %%
# Define the example sentence and the list of sentences to compare

passages = [
    "London has 9,787,426 inhabitants at the 2011 census",
    "London is known for its financial district",
    "London is the capital and largest city of England and the United Kingdom",
    "London is famous for its iconic landmarks, including the Big Ben and the London Eye.",
    "The River Thames flows through the heart of London, adding to its charm and beauty.",
    "London is a multicultural city with a rich history and a diverse population.",
    "The British Museum, located in London, houses a vast collection of art and historical artifacts.",
    "London is a major hub for international travel, with several airports serving the city.",
    "London is home to numerous world-class theaters, including the West End, known for its theatrical productions.",
    "The city has a rich literary history with famous authors like Charles Dickens and Virginia Woolf having lived and written in London.",
    "London has a thriving music scene with venues such as the Royal Albert Hall hosting concerts and events.",
    "The city offers a wide range of dining options, from traditional British pubs to international cuisine.",
    "London's public transportation system, including the London Underground, makes it easy to get around the city.",
    "The city has a diverse and vibrant art scene with numerous galleries and art exhibitions.",
    "London is home to several prestigious universities, making it a center for education and research.",
    "The Tower of London, a historic castle on the River Thames, is a UNESCO World Heritage Site.",
    "London has a reputation for its unpredictable weather, with rain being a common occurrence.",
    "The city is known for its green spaces, including Hyde Park and Regents Park.",
    "London is a major global financial center, with the London Stock Exchange being one of the world's leading stock markets.",
    "London is a popular destination for tourists from all over the world.",
    "The city hosted the 2012 Summer Olympics, which left a lasting legacy of sports facilities and infrastructure.",
    "London is divided into several distinct neighborhoods, each with its own character and charm.",
    "The West End of London is famous for its theaters, shopping, and entertainment.",
    "The Shard, a modern skyscraper in London, offers stunning views of the city from its observation deck.",
    "London is known for its vibrant street markets, selling everything from antiques to street food.",
    "The city is home to numerous world-class museums, including the Natural History Museum and the Tate Modern.",
    "London's history dates back to Roman times, and remnants of the past can still be seen in the city.",
    "The London Eye, a giant observation wheel, provides panoramic views of the city's skyline.",
    "London is a diverse city, with people from all over the world calling it home.",
    "The city is a center for fashion, with famous designers and fashion events taking place here.",
    "London is also known for its historic pubs, many of which have been serving patrons for centuries.",
    "London is famous for its iconic double-decker buses, a symbol of the city's transportation.",
    "The city is home to the historic Buckingham Palace, the official residence of the British monarch.",
    "London is a hub for the tech industry, with many tech startups and innovation centers.",
    "The city's West End theaters host a wide range of musicals and plays, attracting theater enthusiasts from around the world.",
    "London has a thriving food scene, with a diverse range of restaurants offering cuisine from all corners of the globe.",
    "The iconic London Black Cabs are a popular mode of transportation for both locals and tourists.",
    "The city's skyline is constantly changing with new skyscrapers and architectural landmarks.",
    "London is home to several famous street artists, and you can find their work on public walls and buildings.",
    "The Royal Opera House in Covent Garden is a renowned venue for opera and ballet performances.",
    "London is known for its historical connection to the British monarchy, with many royal palaces and castles.",
    "The city's financial district, known as the City of London, is one of the world's major financial centers.",
    "The Victoria and Albert Museum houses an extensive collection of art and design from various time periods and cultures.",
    "The historic neighborhood of Greenwich is known for its maritime history and the Greenwich Prime Meridian.",
    "London's West End shopping streets, such as Oxford Street, are popular for retail therapy.",
    "The city is home to iconic bridges, including Tower Bridge and the Millennium Bridge.",
    "The London Zoo in Regent's Park is one of the world's oldest and most famous zoos.",
    "London's fashion week is a globally recognized event showcasing the latest in fashion trends.",
    "The city has a vibrant LGBTQ+ community, with Soho being a popular nightlife and cultural hub.",
    "The Royal Festival Hall on the Southbank hosts a wide range of cultural events and performances.",
    "London's parks and green spaces are perfect for picnics and outdoor activities during the summer.",
    "The city is a hub for the film and television industry, with many famous productions filmed in London.",
    "London's underground train system, often called the Tube, is one of the oldest in the world.",
    "London Bridge, with its historic and modern incarnations, is an iconic symbol of the city.",
    "The city hosts a wide range of festivals and events throughout the year, celebrating various cultures and interests.",
    "London is known for its red double-decker buses and black cabs, iconic symbols of the city's transportation.",
    "The Thames Barrier, a flood defense system, protects London from tidal surges and flooding.",
    "London has a thriving technology and startup scene, with many tech companies headquartered in the city.",
    "The East End of London is known for its rich history and vibrant street art scene.",
    "The Royal Observatory in Greenwich is the location of the Prime Meridian, dividing the Eastern and Western Hemispheres.",
    "London is a hub for cultural diversity, with various neighborhoods representing different cultures and cuisines.",
    "The city's iconic red buses are a convenient way to navigate the streets of London.",
    "The British Library in London is one of the world's largest libraries, housing a vast collection of books and manuscripts.",
    "London's West End theaters have been the stage for famous musicals like 'Les Misérables' and 'The Phantom of the Opera.'",
    "The city's nightlife includes a wide range of bars, clubs, and live music venues for entertainment.",
    "London is known for its stunning Christmas decorations and markets during the holiday season.",
    "The city's skyline is dominated by architectural landmarks, including the Walkie-Talkie and the Gherkin.",
    "London's public squares, such as Trafalgar Square, host various cultural events and gatherings.",
    "The Notting Hill Carnival is one of Europe's largest street festivals, celebrating Caribbean culture.",
    "The city's financial district, Canary Wharf, is home to many skyscrapers and international businesses.",
    "London's museums, such as the Science Museum and the Victoria and Albert Museum, offer educational experiences for all ages.",
    "The River Thames provides opportunities for river cruises and scenic walks along its banks.",
    "London has a thriving music scene, with live performances ranging from classical to punk rock.",
    "The city's theater district hosts the annual Olivier Awards, celebrating excellence in British theater.",
    "London is home to numerous iconic bridges, each with its own unique design and history.",
    "The Victoria and Albert Museum is renowned for its collection of art, design, and fashion exhibits.",
    "London's parks, like Hampstead Heath, offer green spaces and outdoor activities for relaxation and recreation.",
    "The city's skyline includes the distinctive 'Cheesegrater' and 'The Leadenhall Building' skyscrapers.",
    "London is known for its historical connection to William Shakespeare, with the Globe Theatre hosting Shakespearean plays.",
    "The city's gastronomic scene includes Michelin-starred restaurants and traditional British fare.",
    "London's public transportation system has a rich history, with some stations dating back to the 19th century.",
    "The city's neighborhoods, such as Notting Hill and Chelsea, have unique charm and architecture.",
    "London's diverse food markets, like Borough Market, offer a wide range of culinary delights.",
    "The city's major parks, including Greenwich Park, provide opportunities for outdoor sports and picnics.",
    "London's famous wax museum, Madame Tussauds, features lifelike celebrity figures and historical figures."
]

# Encode the example sentence and the list of sentences using the model
passage_embeddings = model.encode(passages)

# %%
# Encode query
query = 'I am interessted in the East End of London.'
query_embedding = model.encode(query)

# Compute the cosine similarity between the example sentence and the list of sentences
cosine_scores = util.cos_sim(query_embedding, passage_embeddings)

# Find the index of the most similar sentence
most_similar_index = cosine_scores.argmax().item()
cosine_scores_list = cosine_scores.tolist()[0]

# Print the most similar sentence and its similarity score
print(f"Most similar sentence: {passages[most_similar_index]}")
print(f"Similarity score: {cosine_scores_list[most_similar_index]}")
# Out:
# Most similar sentence: The East End of London is known for its rich history and vibrant street art scene.
# Similarity score: 0.4640648066997528
